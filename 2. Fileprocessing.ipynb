# %%
#import relevant libraries
import os


import NLCLIMB_asyn

#NOTE: SUPPRESSES WARNINGS!

import warnings

warnings.simplefilter(action="ignore", category=RuntimeWarning)
#warnings.simplefilter(action="default", category=RuntimeWarning)

# %%
laptop = "C:\\Users\\lnico\\"
homecomp = "C:\\Users\\user\\"
labcomp = "C:\\Users\\User\\"

path2 = "NUS Dropbox\\acclab\\Nicole M Lee\\"
openPath = labcomp + path2 + "PD\\DATA\\"
savefolder = labcomp + path2 + "PD\\Data Compilation\\"

isExist = os.path.exists(savefolder)
if not isExist:
    os.makedirs(savefolder)

listofgenotypes = os.listdir(openPath)
#listofgenotypes = ["elav x 51375_D10", "elav x 51376_D10"]

print (listofgenotypes)
# Out:
# ['Alrm x 95240_D10', 'ddc x 95240_D10', 'ddc x 95240_D20', 'ddc x 95240_D30', 'elav x 51375_D10', 'elav x 51375_D20', 'elav x 51375_D30', 'elav x 51376_D10', 'elav x 51376_D20', 'elav x 51376_D30', 'elav x 8146_D10', 'elav x 8146_D20', 'elav x 8146_D30', 'elav x 8147_D10', 'elav x 8147_D30', 'elav x 95240_D10', 'repo x 95240_D10', 'repo x 95240_D20', 'repo x 95240_D30', 'VT009792 x 51375_D10', 'VT009792 x 51376_D10', 'VT009792 x 8146_D10', 'VT009792 x 95240_D10', 'w1118 x 95240_D10', 'w1118 x 95240_D20', 'w1118 x 95240_D30', 'w1118 x ddc_D10', 'w1118 x ddc_D20', 'w1118 x ddc_D30', 'w1118 x elav_D10', 'w1118 x elav_D20', 'w1118 x elav_D30', 'w1118 x repo_D10', 'w1118 x repo_D20', 'w1118 x repo_D30', 'w1118 x VT009792_D10']

# %%
for line in listofgenotypes:

    filename = openPath + line

    print(filename)

    df_expt, fpsexpt = NLCLIMB_asyn.compilation(filename, line)

    print("fps:", fpsexpt, "||size:", df_expt.shape)
    print("n's: ", (len(df_expt.columns)-2)*0.5)

    df_expt.to_csv(savefolder + line + '.csv')

    print(savefolder + line + '.csv')
    print("COMPLETED!!")
# Out:
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\DATA\Alrm x 95240_D10
# fps: 5 ||size: (450, 104)
# n's:  51.0
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\Data Compilation\Alrm x 95240_D10.csv
# COMPLETED!!
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\DATA\ddc x 95240_D10
# fps: 5 ||size: (450, 202)
# n's:  100.0
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\Data Compilation\ddc x 95240_D10.csv
# COMPLETED!!
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\DATA\ddc x 95240_D20
# fps: 5 ||size: (450, 72)
# n's:  35.0
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\Data Compilation\ddc x 95240_D20.csv
# COMPLETED!!
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\DATA\ddc x 95240_D30
# fps: 5 ||size: (450, 148)
# n's:  73.0
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\Data Compilation\ddc x 95240_D30.csv
# COMPLETED!!
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\DATA\elav x 51375_D10
# fps: 5 ||size: (450, 208)
# n's:  103.0
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\Data Compilation\elav x 51375_D10.csv
# COMPLETED!!
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\DATA\elav x 51375_D20
# fps: 5 ||size: (450, 58)
# n's:  28.0
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\Data Compilation\elav x 51375_D20.csv
# COMPLETED!!
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\DATA\elav x 51375_D30
# fps: 5 ||size: (450, 120)
# n's:  59.0
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\Data Compilation\elav x 51375_D30.csv
# COMPLETED!!
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\DATA\elav x 51376_D10
# fps: 5 ||size: (450, 246)
# n's:  122.0
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\Data Compilation\elav x 51376_D10.csv
# COMPLETED!!
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\DATA\elav x 51376_D20
# fps: 5 ||size: (450, 134)
# n's:  66.0
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\Data Compilation\elav x 51376_D20.csv
# COMPLETED!!
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\DATA\elav x 51376_D30
# fps: 5 ||size: (450, 132)
# n's:  65.0
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\Data Compilation\elav x 51376_D30.csv
# COMPLETED!!
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\DATA\elav x 8146_D10
# fps: 5 ||size: (450, 48)
# n's:  23.0
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\Data Compilation\elav x 8146_D10.csv
# COMPLETED!!
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\DATA\elav x 8146_D20
# fps: 5 ||size: (450, 46)
# n's:  22.0
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\Data Compilation\elav x 8146_D20.csv
# COMPLETED!!
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\DATA\elav x 8146_D30
# fps: 5 ||size: (450, 24)
# n's:  11.0
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\Data Compilation\elav x 8146_D30.csv
# COMPLETED!!
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\DATA\elav x 8147_D10
# fps: 5 ||size: (450, 94)
# n's:  46.0
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\Data Compilation\elav x 8147_D10.csv
# COMPLETED!!
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\DATA\elav x 8147_D30
# fps: 5 ||size: (450, 24)
# n's:  11.0
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\Data Compilation\elav x 8147_D30.csv
# COMPLETED!!
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\DATA\elav x 95240_D10
# fps: 5 ||size: (450, 86)
# n's:  42.0
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\Data Compilation\elav x 95240_D10.csv
# COMPLETED!!
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\DATA\repo x 95240_D10
# fps: 5 ||size: (450, 50)
# n's:  24.0
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\Data Compilation\repo x 95240_D10.csv
# COMPLETED!!
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\DATA\repo x 95240_D20
# fps: 5 ||size: (450, 166)
# n's:  82.0
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\Data Compilation\repo x 95240_D20.csv
# COMPLETED!!
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\DATA\repo x 95240_D30
# fps: 5 ||size: (450, 154)
# n's:  76.0
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\Data Compilation\repo x 95240_D30.csv
# COMPLETED!!
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\DATA\VT009792 x 51375_D10
# fps: 5 ||size: (450, 78)
# n's:  38.0
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\Data Compilation\VT009792 x 51375_D10.csv
# COMPLETED!!
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\DATA\VT009792 x 51376_D10
# fps: 5 ||size: (450, 52)
# n's:  25.0
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\Data Compilation\VT009792 x 51376_D10.csv
# COMPLETED!!
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\DATA\VT009792 x 8146_D10
# fps: 5 ||size: (450, 72)
# n's:  35.0
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\Data Compilation\VT009792 x 8146_D10.csv
# COMPLETED!!
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\DATA\VT009792 x 95240_D10
# fps: 5 ||size: (450, 132)
# n's:  65.0
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\Data Compilation\VT009792 x 95240_D10.csv
# COMPLETED!!
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\DATA\w1118 x 95240_D10
# fps: 5 ||size: (450, 92)
# n's:  45.0
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\Data Compilation\w1118 x 95240_D10.csv
# COMPLETED!!
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\DATA\w1118 x 95240_D20
# fps: 5 ||size: (450, 38)
# n's:  18.0
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\Data Compilation\w1118 x 95240_D20.csv
# COMPLETED!!
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\DATA\w1118 x 95240_D30
# fps: 5 ||size: (450, 146)
# n's:  72.0
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\Data Compilation\w1118 x 95240_D30.csv
# COMPLETED!!
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\DATA\w1118 x ddc_D10
# fps: 5 ||size: (450, 44)
# n's:  21.0
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\Data Compilation\w1118 x ddc_D10.csv
# COMPLETED!!
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\DATA\w1118 x ddc_D20
# fps: 5 ||size: (450, 78)
# n's:  38.0
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\Data Compilation\w1118 x ddc_D20.csv
# COMPLETED!!
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\DATA\w1118 x ddc_D30
# fps: 5 ||size: (450, 112)
# n's:  55.0
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\Data Compilation\w1118 x ddc_D30.csv
# COMPLETED!!
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\DATA\w1118 x elav_D10
# fps: 5 ||size: (450, 210)
# n's:  104.0
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\Data Compilation\w1118 x elav_D10.csv
# COMPLETED!!
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\DATA\w1118 x elav_D20
# fps: 5 ||size: (450, 90)
# n's:  44.0
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\Data Compilation\w1118 x elav_D20.csv
# COMPLETED!!
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\DATA\w1118 x elav_D30
# fps: 5 ||size: (450, 110)
# n's:  54.0
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\Data Compilation\w1118 x elav_D30.csv
# COMPLETED!!
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\DATA\w1118 x repo_D10
# fps: 5 ||size: (450, 68)
# n's:  33.0
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\Data Compilation\w1118 x repo_D10.csv
# COMPLETED!!
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\DATA\w1118 x repo_D20
# fps: 5 ||size: (450, 36)
# n's:  17.0
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\Data Compilation\w1118 x repo_D20.csv
# COMPLETED!!
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\DATA\w1118 x repo_D30
# fps: 5 ||size: (450, 154)
# n's:  76.0
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\Data Compilation\w1118 x repo_D30.csv
# COMPLETED!!
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\DATA\w1118 x VT009792_D10
# fps: 5 ||size: (450, 88)
# n's:  43.0
# C:\Users\User\NUS Dropbox\acclab\Nicole M Lee\PD\Data Compilation\w1118 x VT009792_D10.csv
# COMPLETED!!
