# %%
#import relevant libraries
import os
import shutil

#NOTE: SUPPRESSES WARNINGS!

import warnings

warnings.simplefilter(action="ignore", category=RuntimeWarning)
#warnings.simplefilter(action="default", category=RuntimeWarning)

# %%
#initial file processing

laptop = "C:\\Users\\lnico\\"
homecomp = "C:\\Users\\user\\"
labcomp = "C:\\Users\\User\\"

path2 = "NUS Dropbox\\acclab\\Nicole M Lee\\"
finaldestination  =  "Raw data files\\PD\\"
openPath = labcomp + path2 + finaldestination
savePath = labcomp + path2 + "PD\\DATA\\"

files = os.listdir(openPath)

print (files)
# Out:
# ['20260819', '20260829', '20260903', '20260908', '20260909', '20260910', '20260911', '20260914', '20260915', '20260916', '20260917', '20260918']

# %%
#copies and renames files

for f in files:
    
    Path1 = openPath + f  #returns me the date folder 20260910
    
    files2 = os.listdir(Path1)  #returns me 95240 x ddc_D10, elav x 51375_D10 etc etc

    for g in files2:
        
        Path2 = Path1 + "\\" + g
        destination = savePath + g
        
        isExist = os.path.exists(destination)
        if not isExist:
            os.makedirs(destination)
        #print (destination)
        ####################################

        files3 = os.listdir(Path2)  #returns me ClimbLog, ClimbReport, MetaData etc etc

        for j in files3: #opens each excel file
            if j.startswith("ClimbLog"):
                jj= os.path.splitext(j)[0]
                renamed = jj + '_' + g + ".csv"  #new file name
                if not os.path.exists(destination + "\\" + renamed):
                    print(renamed)
                    countlogfile = shutil.copy(Path2 + "\\" + j, destination + "\\" + renamed)
print("done!")
# Out:
# ClimbLog_2026-08-19_15-07-08_elav x 51375_D10.csv
# ClimbLog_2026-08-19_15-38-01_elav x 51375_D10.csv
# ClimbLog_2026-08-19_14-27-46_elav x 51376_D10.csv
# ClimbLog_2026-08-19_15-53-07_elav x 8146_D10.csv
# ClimbLog_2026-08-19_11-09-05_elav x 8147_D10.csv
# ClimbLog_2026-08-19_11-29-08_elav x 8147_D10.csv
# ClimbLog_2026-08-19_10-37-15_elav x 95240_D10.csv
# ClimbLog_2026-08-19_10-52-09_elav x 95240_D10.csv
# ClimbLog_2026-08-29_10-02-43_elav x 51375_D10.csv
# ClimbLog_2026-08-29_10-23-09_elav x 51376_D10.csv
# ClimbLog_2026-08-29_10-52-56_elav x 51376_D10.csv
# ClimbLog_2026-09-03_18-10-15_95240 x ddc_D10.csv
# ClimbLog_2026-09-03_18-23-33_95240 x ddc_D10.csv
# ClimbLog_2026-09-04_10-29-24_95240 x ddc_D10.csv
# ClimbLog_2026-09-03_17-30-17_elav x 51375_D10.csv
# ClimbLog_2026-09-03_17-41-05_elav x 51375_D10.csv
# ClimbLog_2026-09-04_11-27-01_elav x 51375_D10.csv
# ClimbLog_2026-09-03_17-49-18_elav x 51375_D30.csv
# ClimbLog_2026-09-03_18-02-58_elav x 51375_D30.csv
# ClimbLog_2026-09-03_16-10-01_elav x 51376_D10.csv
# ClimbLog_2026-09-03_16-23-00_elav x 51376_D10.csv
# ClimbLog_2026-09-03_12-44-30_elav x 51376_D30.csv
# ClimbLog_2026-09-03_13-03-56_elav x 51376_D30.csv
# ClimbLog_2026-09-03_10-08-00_elav x 8146_D30.csv
# ClimbLog_2026-09-03_12-21-02_elav x 8147_D30.csv
# ClimbLog_2026-09-03_12-07-23_w1118 x ddc_D10.csv
# ClimbLog_2026-09-03_16-34-41_w1118 x elav_D10.csv
# ClimbLog_2026-09-03_16-54-51_w1118 x elav_D10.csv
# ClimbLog_2026-09-03_17-15-19_w1118 x elav_D10.csv
# ClimbLog_2026-09-04_10-43-16_w1118 x elav_D10.csv
# ClimbLog_2026-09-04_10-55-48_w1118 x elav_D10.csv
# ClimbLog_2026-09-03_15-54-06_w1118 x repo_D10.csv
# ClimbLog_2026-09-08_16-05-00_95240 x ddc_D10.csv
# ClimbLog_2026-09-08_16-44-18_95240 x ddc_D10.csv
# ClimbLog_2026-09-08_17-05-08_elav x 51375_D10.csv
# ClimbLog_2026-09-08_15-25-12_elav x 51376_D10.csv
# ClimbLog_2026-09-08_15-41-24_elav x 51376_D10.csv
# ClimbLog_2026-09-08_16-22-43_w1118 x elav_D10.csv
# ClimbLog_2026-09-08_15-12-18_w1118 x repo_D10.csv
# ClimbLog_2026-09-09_15-16-15_95240 x ddc_D20.csv
# ClimbLog_2026-09-09_14-27-03_95240 x repo_D20.csv
# ClimbLog_2026-09-09_14-47-15_95240 x repo_D20.csv
# ClimbLog_2026-09-09_15-03-26_95240 x repo_D20.csv
# ClimbLog_2026-09-09_14-05-07_elav x 51376_D20.csv
# ClimbLog_2026-09-09_14-12-24_elav x 51376_D20.csv
# ClimbLog_2026-09-09_15-28-44_elav x 8146_D20.csv
# ClimbLog_2026-09-10_15-45-55_95240 x ddc_D10.csv
# ClimbLog_2026-09-10_15-59-31_95240 x ddc_D10.csv
# ClimbLog_2026-09-10_11-56-11_95240 x ddc_D20.csv
# ClimbLog_2026-09-10_14-03-28_95240 x repo_D10.csv
# ClimbLog_2026-09-10_11-23-03_95240 x repo_D20.csv
# ClimbLog_2026-09-10_15-03-34_elav x 51375_D10.csv
# ClimbLog_2026-09-10_12-26-52_elav x 51375_D20.csv
# ClimbLog_2026-09-10_14-51-16_elav x 51376_D10.csv
# ClimbLog_2026-09-10_13-43-14_elav x 51376_D20.csv
# ClimbLog_2026-09-10_10-59-41_elav x 8146_D20.csv
# ClimbLog_2026-09-10_14-27-04_elav x 95240_D10.csv
# ClimbLog_2026-09-10_14-10-58_w1118 x 95240_D10.csv
# ClimbLog_2026-09-10_11-15-06_w1118 x 95240_D20.csv
# ClimbLog_2026-09-10_14-36-37_w1118 x ddc_D10.csv
# ClimbLog_2026-09-10_11-32-49_w1118 x ddc_D20.csv
# ClimbLog_2026-09-10_11-42-36_w1118 x ddc_D20.csv
# ClimbLog_2026-09-10_15-29-04_w1118 x elav_D10.csv
# ClimbLog_2026-09-10_13-29-52_w1118 x elav_D20.csv
# ClimbLog_2026-09-10_13-55-54_w1118 x elav_D20.csv
# ClimbLog_2026-09-10_15-15-39_w1118 x repo_D10.csv
# ClimbLog_2026-09-10_13-13-43_w1118 x repo_D20.csv
# ClimbLog_2026-09-11_12-29-44_95240 x ddc_D10.csv
# ClimbLog_2026-09-11_10-37-56_95240 x repo_D10.csv
# ClimbLog_2026-09-11_11-19-12_elav x 51375_D10.csv
# ClimbLog_2026-09-11_11-31-37_elav x 51376_D10.csv
# ClimbLog_2026-09-11_11-07-09_elav x 8146_D10.csv
# ClimbLog_2026-09-11_12-41-21_elav x 8147_D10.csv
# ClimbLog_2026-09-11_10-50-21_w1118 x 95240_D10.csv
# ClimbLog_2026-09-11_12-56-38_w1118 x repo_D10.csv
# ClimbLog_2026-09-14_11-24-29_95240 x repo_D20.csv
# ClimbLog_2026-09-14_14-03-00_Alrm x 95240_D10.csv
# ClimbLog_2026-09-14_13-05-42_elav x 51376_D20.csv
# ClimbLog_2026-09-14_10-59-44_elav x 8147_D10.csv
# ClimbLog_2026-09-14_13-24-27_VT009792 x 51375_D10.csv
# ClimbLog_2026-09-14_13-37-28_VT009792 x 51376_D10.csv
# ClimbLog_2026-09-14_14-24-06_VT009792 x 8146_D10.csv
# ClimbLog_2026-09-14_11-43-22_VT009792 x 95240_D10.csv
# ClimbLog_2026-09-14_11-10-47_w1118 x 95240_D10.csv
# ClimbLog_2026-09-14_11-56-44_w1118 x repo_D20.csv
# ClimbLog_2026-09-14_13-46-25_w1118 x VT009792_D10.csv
# ClimbLog_2026-09-15_14-03-23_95240 x ddc_D20.csv
# ClimbLog_2026-09-15_14-48-30_95240 x repo_D20.csv
# ClimbLog_2026-09-15_14-34-08_elav x 51375_D20.csv
# ClimbLog_2026-09-15_14-17-45_elav x 51376_D20.csv
# ClimbLog_2026-09-15_13-48-08_w1118 x elav_D20.csv
# ClimbLog_2026-09-16_14-15-32_95240 x ddc_D30.csv
# ClimbLog_2026-09-16_14-32-01_95240 x ddc_D30.csv
# ClimbLog_2026-09-16_13-31-21_95240 x repo_D30.csv
# ClimbLog_2026-09-16_13-42-41_95240 x repo_D30.csv
# ClimbLog_2026-09-16_13-56-16_95240 x repo_D30.csv
# ClimbLog_2026-09-16_17-28-23_Alrm x 95240_D10.csv
# ClimbLog_2026-09-16_17-51-50_Alrm x 95240_D10.csv
# ClimbLog_2026-09-16_15-43-03_elav x 51375_D20.csv
# ClimbLog_2026-09-16_15-29-51_elav x 51376_D20.csv
# ClimbLog_2026-09-16_12-36-10_elav x 51376_D30.csv
# ClimbLog_2026-09-16_13-05-07_elav x 51376_D30.csv
# ClimbLog_2026-09-16_16-53-49_VT009792 x 51376_D10.csv
# ClimbLog_2026-09-16_17-08-01_VT009792 x 8146_D10.csv
# ClimbLog_2026-09-16_16-39-16_w1118 x 95240_D10.csv
# ClimbLog_2026-09-16_12-51-41_w1118 x ddc_D30.csv
# ClimbLog_2026-09-16_13-17-43_w1118 x ddc_D30.csv
# ClimbLog_2026-09-16_15-57-21_w1118 x elav_D20.csv
# ClimbLog_2026-09-16_14-48-16_w1118 x repo_D30.csv
# ClimbLog_2026-09-16_14-58-24_w1118 x repo_D30.csv
# ClimbLog_2026-09-16_15-15-40_w1118 x repo_D30.csv
# ClimbLog_2026-09-16_16-13-10_w1118 x VT009792_D10.csv
# ClimbLog_2026-09-16_16-25-05_w1118 x VT009792_D10.csv
# ClimbLog_2026-09-17_11-16-32_95240 x ddc_D30.csv
# ClimbLog_2026-09-17_11-26-52_95240 x ddc_D30.csv
# ClimbLog_2026-09-17_11-00-10_95240 x repo_D30.csv
# ClimbLog_2026-09-17_13-25-00_elav x 51375_D30.csv
# ClimbLog_2026-09-17_13-36-33_elav x 51375_D30.csv
# ClimbLog_2026-09-17_12-28-43_elav x 51376_D30.csv
# ClimbLog_2026-09-17_13-50-56_VT009792 x 51375_D10.csv
# ClimbLog_2026-09-17_14-00-55_VT009792 x 95240_D10.csv
# ClimbLog_2026-09-17_14-15-08_VT009792 x 95240_D10.csv
# ClimbLog_2026-09-17_14-31-13_VT009792 x 95240_D10.csv
# ClimbLog_2026-09-17_09-38-03_w1118 x 95240_D30.csv
# ClimbLog_2026-09-17_09-50-40_w1118 x 95240_D30.csv
# ClimbLog_2026-09-17_10-04-12_w1118 x 95240_D30.csv
# ClimbLog_2026-09-17_10-17-48_w1118 x 95240_D30.csv
# ClimbLog_2026-09-17_09-26-19_w1118 x ddc_D30.csv
# ClimbLog_2026-09-17_11-41-39_w1118 x elav_D30.csv
# ClimbLog_2026-09-17_11-57-47_w1118 x elav_D30.csv
# ClimbLog_2026-09-17_12-07-09_w1118 x elav_D30.csv
# ClimbLog_2026-09-17_10-28-28_w1118 x repo_D30.csv
# ClimbLog_2026-09-17_10-46-02_w1118 x repo_D30.csv
# ClimbLog_2026-09-18_10-35-06_95240 x ddc_D30.csv
# ClimbLog_2026-09-18_11-30-35_95240 x repo_D20.csv
# ClimbLog_2026-09-18_10-19-22_95240 x repo_D30.csv
# ClimbLog_2026-09-18_14-07-06_Alrm x 95240_D10.csv
# ClimbLog_2026-09-18_14-38-11_VT009792 x 51375_D10.csv
# ClimbLog_2026-09-18_14-22-32_VT009792 x 8146_D10.csv
# ClimbLog_2026-09-18_15-04-16_VT009792 x 95240_D10.csv
# ClimbLog_2026-09-18_14-52-13_w1118 x 95240_D10.csv
# ClimbLog_2026-09-18_11-48-48_w1118 x 95240_D20.csv
# ClimbLog_2026-09-18_10-06-29_w1118 x 95240_D30.csv
# ClimbLog_2026-09-18_13-52-28_w1118 x ddc_D20.csv
# ClimbLog_2026-09-18_09-53-40_w1118 x ddc_D30.csv
# ClimbLog_2026-09-18_11-16-59_w1118 x elav_D30.csv
# ClimbLog_2026-09-18_11-00-41_w1118 x repo_D30.csv
# ClimbLog_2026-09-18_15-19-14_w1118 x VT009792_D10.csv
# done!
