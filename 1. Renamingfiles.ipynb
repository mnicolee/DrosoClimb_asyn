# %%
#import relevant libraries
import os
import shutil

#NOTE: SUPPRESSES WARNINGS!

import warnings

warnings.simplefilter(action="ignore", category=RuntimeWarning)
#warnings.simplefilter(action="default", category=RuntimeWarning)

# %%
#initial file processing

laptop = "C:\\Users\\lnico\\"
homecomp = "C:\\Users\\user\\"
labcomp = "C:\\Users\\User\\"

path2 = "NUS Dropbox\\acclab\\Nicole M Lee\\"
finaldestination  =  "Raw data files\\PD\\"
openPath = labcomp + path2 + finaldestination
savePath = labcomp + path2 + "PD\\DATA\\"

files = os.listdir(openPath)
files = ["20260921"]
print (files)
# Out:
# ['20260921']

# %%
#copies and renames files

for f in files:
    
    Path1 = openPath + f  #returns me the date folder 20260910
    
    files2 = os.listdir(Path1)  #returns me 95240 x ddc_D10, elav x 51375_D10 etc etc

    for g in files2:
        
        Path2 = Path1 + "\\" + g
        destination = savePath + g
        
        isExist = os.path.exists(destination)
        if not isExist:
            os.makedirs(destination)
        #print (destination)
        ####################################

        files3 = os.listdir(Path2)  #returns me ClimbLog, ClimbReport, MetaData etc etc

        for j in files3: #opens each excel file
            if j.startswith("ClimbLog"):
                jj= os.path.splitext(j)[0]
                renamed = jj + '_' + g + ".csv"  #new file name
                if not os.path.exists(destination + "\\" + renamed):
                    print(renamed)
                    countlogfile = shutil.copy(Path2 + "\\" + j, destination + "\\" + renamed)
print("done!")
# Out:
# ClimbLog_2026-09-22_15-26-12_95240 x ddc_D20.csv
# ClimbLog_2026-09-22_14-55-19_Alrm x 95240_D20.csv
# ClimbLog_2026-09-22_15-04-28_Alrm x 95240_D20.csv
# ClimbLog_2026-09-22_15-15-03_Alrm x 95240_D20.csv
# ClimbLog_2026-09-22_13-20-57_elav x 51375_D20.csv
# ClimbLog_2026-09-22_14-25-25_elav x 51376_D20.csv
# ClimbLog_2026-09-22_11-49-42_elav x 8146_D20.csv
# ClimbLog_2026-09-22_13-49-43_elav x 8147_D20.csv
# ClimbLog_2026-09-22_13-58-55_elav x 8147_D20.csv
# ClimbLog_2026-09-21_12-53-31_elav x 95240_D20.csv
# ClimbLog_2026-09-22_12-13-46_VT009792 x 51375_D20.csv
# ClimbLog_2026-09-22_15-50-05_VT009792 x 51376_D20.csv
# ClimbLog_2026-09-22_14-44-53_VT009792 x 8146_D20.csv
# ClimbLog_2026-09-22_14-11-24_VT009792 x 95240_D20.csv
# ClimbLog_2026-09-22_14-34-33_VT009792 x 95240_D20.csv
# ClimbLog_2026-09-22_11-22-47_w1118 x 95240_D20.csv
# ClimbLog_2026-09-22_11-31-24_w1118 x 95240_D20.csv
# ClimbLog_2026-09-22_11-40-41_w1118 x 95240_D20.csv
# ClimbLog_2026-09-21_13-18-52_w1118 x elav_D20.csv
# ClimbLog_2026-09-22_15-37-08_w1118 x VT009792_D20.csv
# done!
